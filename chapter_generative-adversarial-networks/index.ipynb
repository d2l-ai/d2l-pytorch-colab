# %% [markdown]
# # Redes Adversariais Generativas
# :label:`chap_gans`
#
# :begin_tab:toc
#  - [gan](gan.ipynb)
#  - [dcgan](dcgan.ipynb)
# :end_tab:
#
# <!--stackedit_data:
# eyJoaXN0b3J5IjpbNzAzNjg4MDU3LC0xMjY2NzQwNjE0XX0=
# -->
